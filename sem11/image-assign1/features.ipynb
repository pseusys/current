# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

learning_rates += [10 ** -p for p in range(13, 0, -1)]
regularization_strengths += [10 ** p for p in range(-3, 13)]

for lr, rs in [(lr, rs) for lr in learning_rates for rs in regularization_strengths]:
    svm = LinearSVM()
    svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs, num_iters=100)
    train_acc = np.mean(y_train == svm.predict(X_train_feats))
    val_acc = np.mean(y_val == svm.predict(X_val_feats))
    results[(lr, rs)] = (train_acc, val_acc)
    if val_acc > best_val:
        best_val, best_svm = val_acc, svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# /home/pseusys/Documents/current/sem11/image-assign1/cs231n/classifiers/linear_svm.py:101: RuntimeWarning: overflow encountered in scalar multiply
#   loss = (np.sum(margins) / num_train) + reg * np.sum(W * W)
# /home/pseusys/.cache/pypoetry/virtualenvs/cs231n-JExy_8Er-py3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/pseusys/Documents/current/sem11/image-assign1/cs231n/classifiers/linear_svm.py:101: RuntimeWarning: overflow encountered in multiply
#   loss = (np.sum(margins) / num_train) + reg * np.sum(W * W)
# /home/pseusys/Documents/current/sem11/image-assign1/cs231n/classifiers/linear_svm.py:119: RuntimeWarning: overflow encountered in multiply
#   dW = (X.T.dot(margins) / num_train) + reg * W
# /home/pseusys/Documents/current/sem11/image-assign1/cs231n/classifiers/linear_svm.py:98: RuntimeWarning: invalid value encountered in subtract
#   margins = np.maximum(0, scores - correct_class_scores + 1)
# lr 1.000000e-13 reg 1.000000e-03 train accuracy: 0.115388 val accuracy: 0.113000
# lr 1.000000e-13 reg 1.000000e-02 train accuracy: 0.102592 val accuracy: 0.125000
# lr 1.000000e-13 reg 1.000000e-01 train accuracy: 0.128653 val accuracy: 0.134000
# lr 1.000000e-13 reg 1.000000e+00 train accuracy: 0.114878 val accuracy: 0.102000
# lr 1.000000e-13 reg 1.000000e+01 train accuracy: 0.067306 val accuracy: 0.068000
# lr 1.000000e-13 reg 1.000000e+02 train accuracy: 0.080204 val accuracy: 0.091000
# lr 1.000000e-13 reg 1.000000e+03 train accuracy: 0.094837 val accuracy: 0.097000
# lr 1.000000e-13 reg 1.000000e+04 train accuracy: 0.083347 val accuracy: 0.080000
# lr 1.000000e-13 reg 5.000000e+04 train accuracy: 0.089551 val accuracy: 0.088000
# lr 1.000000e-13 reg 1.000000e+05 train accuracy: 0.076673 val accuracy: 0.075000
# lr 1.000000e-13 reg 5.000000e+05 train accuracy: 0.110796 val accuracy: 0.117000
# lr 1.000000e-13 reg 1.000000e+06 train accuracy: 0.112694 val accuracy: 0.114000
# lr 1.000000e-13 reg 5.000000e+06 train accuracy: 0.105102 val accuracy: 0.098000
# lr 1.000000e-13 reg 1.000000e+07 train accuracy: 0.093755 val accuracy: 0.078000
# lr 1.000000e-13 reg 1.000000e+08 train accuracy: 0.104306 val accuracy: 0.097000
# lr 1.000000e-13 reg 1.000000e+09 train accuracy: 0.115347 val accuracy: 0.108000
# lr 1.000000e-13 reg 1.000000e+10 train accuracy: 0.111694 val accuracy: 0.124000
# lr 1.000000e-13 reg 1.000000e+11 train accuracy: 0.079347 val accuracy: 0.074000
# lr 1.000000e-13 reg 1.000000e+12 train accuracy: 0.121122 val accuracy: 0.138000
# lr 1.000000e-12 reg 1.000000e-03 train accuracy: 0.100000 val accuracy: 0.105000
# lr 1.000000e-12 reg 1.000000e-02 train accuracy: 0.111980 val accuracy: 0.108000
# lr 1.000000e-12 reg 1.000000e-01 train accuracy: 0.104776 val accuracy: 0.116000
# lr 1.000000e-12 reg 1.000000e+00 train accuracy: 0.088490 val accuracy: 0.088000
# lr 1.000000e-12 reg 1.000000e+01 train accuracy: 0.101714 val accuracy: 0.089000
# lr 1.000000e-12 reg 1.000000e+02 train accuracy: 0.102082 val accuracy: 0.096000
# lr 1.000000e-12 reg 1.000000e+03 train accuracy: 0.089959 val accuracy: 0.105000
# lr 1.000000e-12 reg 1.000000e+04 train accuracy: 0.080000 val accuracy: 0.079000
# lr 1.000000e-12 reg 5.000000e+04 train accuracy: 0.086367 val accuracy: 0.081000
# lr 1.000000e-12 reg 1.000000e+05 train accuracy: 0.076796 val accuracy: 0.091000
# lr 1.000000e-12 reg 5.000000e+05 train accuracy: 0.115347 val accuracy: 0.099000
# lr 1.000000e-12 reg 1.000000e+06 train accuracy: 0.108367 val accuracy: 0.079000
# lr 1.000000e-12 reg 5.000000e+06 train accuracy: 0.107224 val accuracy: 0.097000
# lr 1.000000e-12 reg 1.000000e+07 train accuracy: 0.101816 val accuracy: 0.093000
# lr 1.000000e-12 reg 1.000000e+08 train accuracy: 0.084122 val accuracy: 0.088000
# lr 1.000000e-12 reg 1.000000e+09 train accuracy: 0.095959 val accuracy: 0.103000
# lr 1.000000e-12 reg 1.000000e+10 train accuracy: 0.093918 val accuracy: 0.087000
# lr 1.000000e-12 reg 1.000000e+11 train accuracy: 0.108653 val accuracy: 0.107000
# lr 1.000000e-12 reg 1.000000e+12 train accuracy: 0.329898 val accuracy: 0.337000
# lr 1.000000e-11 reg 1.000000e-03 train accuracy: 0.099306 val accuracy: 0.094000
# lr 1.000000e-11 reg 1.000000e-02 train accuracy: 0.091082 val accuracy: 0.083000
# lr 1.000000e-11 reg 1.000000e-01 train accuracy: 0.099612 val accuracy: 0.094000
# lr 1.000000e-11 reg 1.000000e+00 train accuracy: 0.112571 val accuracy: 0.111000
# lr 1.000000e-11 reg 1.000000e+01 train accuracy: 0.131959 val accuracy: 0.126000
# lr 1.000000e-11 reg 1.000000e+02 train accuracy: 0.102816 val accuracy: 0.136000
# lr 1.000000e-11 reg 1.000000e+03 train accuracy: 0.120939 val accuracy: 0.100000
# lr 1.000000e-11 reg 1.000000e+04 train accuracy: 0.095510 val accuracy: 0.116000
# lr 1.000000e-11 reg 5.000000e+04 train accuracy: 0.112265 val accuracy: 0.105000
# lr 1.000000e-11 reg 1.000000e+05 train accuracy: 0.107694 val accuracy: 0.118000
# lr 1.000000e-11 reg 5.000000e+05 train accuracy: 0.087163 val accuracy: 0.096000
# lr 1.000000e-11 reg 1.000000e+06 train accuracy: 0.096204 val accuracy: 0.105000
# lr 1.000000e-11 reg 5.000000e+06 train accuracy: 0.080122 val accuracy: 0.086000
# lr 1.000000e-11 reg 1.000000e+07 train accuracy: 0.112388 val accuracy: 0.133000
# lr 1.000000e-11 reg 1.000000e+08 train accuracy: 0.103673 val accuracy: 0.120000
# lr 1.000000e-11 reg 1.000000e+09 train accuracy: 0.108714 val accuracy: 0.116000
# lr 1.000000e-11 reg 1.000000e+10 train accuracy: 0.100653 val accuracy: 0.098000
# lr 1.000000e-11 reg 1.000000e+11 train accuracy: 0.330388 val accuracy: 0.316000
# lr 1.000000e-11 reg 1.000000e+12 train accuracy: 0.103980 val accuracy: 0.088000
# lr 1.000000e-10 reg 1.000000e-03 train accuracy: 0.117714 val accuracy: 0.117000
# lr 1.000000e-10 reg 1.000000e-02 train accuracy: 0.106918 val accuracy: 0.105000
# lr 1.000000e-10 reg 1.000000e-01 train accuracy: 0.098673 val accuracy: 0.096000
# lr 1.000000e-10 reg 1.000000e+00 train accuracy: 0.114673 val accuracy: 0.114000
# lr 1.000000e-10 reg 1.000000e+01 train accuracy: 0.097796 val accuracy: 0.100000
# lr 1.000000e-10 reg 1.000000e+02 train accuracy: 0.098980 val accuracy: 0.084000
# lr 1.000000e-10 reg 1.000000e+03 train accuracy: 0

# lr 1.000000e-02 reg 1.000000e+00 train accuracy: 0.482959 val accuracy: 0.468000
# lr 1.000000e-02 reg 1.000000e+01 train accuracy: 0.433633 val accuracy: 0.425000
# lr 1.000000e-02 reg 1.000000e+02 train accuracy: 0.324551 val accuracy: 0.332000
# lr 1.000000e-02 reg 1.000000e+03 train accuracy: 0.044327 val accuracy: 0.054000
# lr 1.000000e-02 reg 1.000000e+04 train accuracy: 0.097898 val accuracy: 0.116000
# lr 1.000000e-02 reg 5.000000e+04 train accuracy: 0.120510 val accuracy: 0.117000
# lr 1.000000e-02 reg 1.000000e+05 train accuracy: 0.108306 val accuracy: 0.111000
# lr 1.000000e-02 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+09 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+10 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+11 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+12 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e-03 train accuracy: 0.475653 val accuracy: 0.472000
# lr 1.000000e-01 reg 1.000000e-02 train accuracy: 0.481531 val accuracy: 0.477000
# lr 1.000000e-01 reg 1.000000e-01 train accuracy: 0.472102 val accuracy: 0.471000
# lr 1.000000e-01 reg 1.000000e+00 train accuracy: 0.430796 val accuracy: 0.428000
# lr 1.000000e-01 reg 1.000000e+01 train accuracy: 0.310224 val accuracy: 0.307000
# lr 1.000000e-01 reg 1.000000e+02 train accuracy: 0.015816 val accuracy: 0.013000
# lr 1.000000e-01 reg 1.000000e+03 train accuracy: 0.044306 val accuracy: 0.040000
# lr 1.000000e-01 reg 1.000000e+04 train accuracy: 0.107735 val accuracy: 0.116000
# lr 1.000000e-01 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+09 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+10 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+11 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+12 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved: 0.489000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.472

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_val_accuracy = -1

decay = 0.95
batch_size = 200

learning_rates = [10 ** -p for p in range(7, 0, -1)]
epochs = [5, 10, 15, 20]

for lr, ep in [(lr, ep) for lr in learning_rates for ep in epochs]:
    parameters = {
        "optim_config": {
            "learning_rate": lr
        },
        "lr_decay": decay,
        "num_epochs": ep,
        "batch_size": batch_size,
        "verbose": False
    }
    solver = Solver(net, data, **parameters)
    solver.train()
    if solver.val_acc_history[-1] > best_val_accuracy:
        best_val_accuracy = solver.val_acc_history[-1]
        print(f"Better accuracy {best_val_accuracy} found for params: {parameters}")
        best_net = net

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# Better accuracy 0.082 found for params: {'optim_config': {'learning_rate': 1e-07}, 'lr_decay': 0.95, 'num_epochs': 5, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.084 found for params: {'optim_config': {'learning_rate': 1e-06}, 'lr_decay': 0.95, 'num_epochs': 20, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.085 found for params: {'optim_config': {'learning_rate': 1e-05}, 'lr_decay': 0.95, 'num_epochs': 5, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.088 found for params: {'optim_config': {'learning_rate': 1e-05}, 'lr_decay': 0.95, 'num_epochs': 10, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.092 found for params: {'optim_config': {'learning_rate': 1e-05}, 'lr_decay': 0.95, 'num_epochs': 15, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.103 found for params: {'optim_config': {'learning_rate': 0.0001}, 'lr_decay': 0.95, 'num_epochs': 5, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.138 found for params: {'optim_config': {'learning_rate': 0.0001}, 'lr_decay': 0.95, 'num_epochs': 10, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.173 found for params: {'optim_config': {'learning_rate': 0.0001}, 'lr_decay': 0.95, 'num_epochs': 15, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.179 found for params: {'optim_config': {'learning_rate': 0.001}, 'lr_decay': 0.95, 'num_epochs': 5, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.289 found for params: {'optim_config': {'learning_rate': 0.001}, 'lr_decay': 0.95, 'num_epochs': 10, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.303 found for params: {'optim_config': {'learning_rate': 0.001}, 'lr_decay': 0.95, 'num_epochs': 15, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.387 found for params: {'optim_config': {'learning_rate': 0.01}, 'lr_decay': 0.95, 'num_epochs': 10, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.497 found for params: {'optim_config': {'learning_rate': 0.01}, 'lr_decay': 0.95, 'num_epochs': 15, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.518 found for params: {'optim_config': {'learning_rate': 0.01}, 'lr_decay': 0.95, 'num_epochs': 20, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.555 found for params: {'optim_config': {'learning_rate': 0.1}, 'lr_decay': 0.95, 'num_epochs': 5, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.601 found for params: {'optim_config': {'learning_rate': 0.1}, 'lr_decay': 0.95, 'num_epochs': 10, 'batch_size': 200, 'verbose': False}
# Better accuracy 0.614 found for params: {'optim_config': {'learning_rate': 0.1}, 'lr_decay': 0.95, 'num_epochs': 15, 'batch_size': 200, 'verbose': False}

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.594
